# %%
import jieba
import jieba.analyse
import re
import pandas as pd
import matplotlib.pyplot as plt

print("helloWorld")
print("testcommit")


def HighFrequency():
    txt = open("HW1.txt", encoding="utf-8").read()
    ch =re.compile("[\u4e00-\u9fa5]")
    hyphenationWord =  "".join(ch.findall(txt))
    cut = jieba.lcut(hyphenationWord)

    counts = {}
    for i in cut :
        if(len(i)>1):
            counts[i] = counts.get(i,0) + 1

    items = list(counts.items())  
    items.sort(key=lambda x:x[1], reverse=True)

    i=0
    while True:
        word, count = items[i]  
        i+=1
        if i==100:
            break

    df = pd.DataFrame(items, columns = ["word", "Frequncy"]).sort_values(['Frequncy'],ascending=[False])[0:100]
    print('High_Frequency_Table:',df)
    print('Frequency_Table:')
    chart = df.plot( kind ='bar',
                    title = 'word/Frequncy',
                    xlabel = 'word',
                    ylabel = 'Frequncy',
                    figsize = (35,15))
    plt.show()

HighFrequency()
# Out:
# helloWorld
# testcommit
# High_Frequency_Table:    word  Frequncy
# 0    八卦      1115
# 1    什麼       961
# 2    怎麼       555
# 3    台灣       537
# 4   是不是       444
# ..  ...       ...
# 95   高雄        46
# 96   男生        46
# 97   好像        45
# 98   代表        45
# 99   最好        45
#
# [100 rows x 2 columns]
# Frequency_Table:
